# %% [markdown]
# ## Enoncé :
# À partir des datasets `population_communes.csv` et `surface_departements.csv`, créer un nouveau dataset qui contient une ligne par département, avec ces colonnes:
#
# - la somme des "Population municipale" du département
# - la somme des "Population totale" du département (pour l'explication de la distinction entre "Population municipale" et "Population totale", voir: https://www.insee.fr/fr/metadonnees/definition/c1270)
# - la part (en pourcentage) de la population municipale par rapport à la population totale
# - la part (en pourcentage) de la population (municipale) du département au sein de sa région
# - la densité de la population (municipale) en nb d'habitants / km2
#
# (Le dataset final devrait ressembler à `result-exo-cc.csv`)
#
# Sites intéressants pour cet exo :
# * https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
# * https://www.datacamp.com/community/tutorials/joining-dataframes-pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('population_communes.csv')

# %%
df
# Out:
#       Code département  Code canton  Code arrondissement  Code région  \
# 0                   64         27.0                    3           75
# 1                   64         27.0                    3           75
# 2                   55         10.0                    2           44
# 3                   55         10.0                    2           44
# 4                   60         11.0                    1           32
# ...                ...          ...                  ...          ...
# 70759               62         38.0                    1           32
# 70760               51          6.0                    2           44
# 70761               02          6.0                    2           32
# 70762               51          6.0                    2           44
# 70763               02          6.0                    2           32
#
#       Nom de la commune  Code commune    Nom de la région  \
# 0                  Aast             1  Nouvelle-Aquitaine
# 1                  Aast             1  Nouvelle-Aquitaine
# 2            Abainville             1           Grand Est
# 3            Abainville             1           Grand Est
# 4             Abancourt             1     Hauts-de-France
# ...                 ...           ...                 ...
# 70759    Œuf-en-Ternois           633     Hauts-de-France
# 70760            Œuilly           410           Grand Est
# 70761            Œuilly           565     Hauts-de-France
# 70762            Œuilly           410           Grand Est
# 70763            Œuilly           565     Hauts-de-France
#
#                     variable  value
# 0          Population totale    184
# 1      Population municipale    177
# 2          Population totale    310
# 3      Population municipale    305
# 4          Population totale    658
# ...                      ...    ...
# 70759  Population municipale    251
# 70760  Population municipale    635
# 70761      Population totale    292
# 70762      Population totale    645
# 70763  Population municipale    290
#
# [70764 rows x 9 columns]

# %%
surface = pd.read_csv('surface_departements.csv')

# %%
surface
# Out:
#     code_insee               nom  surf_km2
# 0          974        La Réunion    2505.0
# 1           11              Aude    6343.0
# 2           43       Haute-Loire    5003.0
# 3           13  Bouches-du-Rhône    5247.0
# 4           47    Lot-et-Garonne    5385.0
# ..         ...               ...       ...
# 96          56          Morbihan    6870.0
# 97          25             Doubs    5256.0
# 98          39              Jura    5049.0
# 99          07           Ardèche    5566.0
# 100         30              Gard    5875.0
#
# [101 rows x 3 columns]

# %%
df = df.groupby(['Code région', 'Code département', 'variable', 'value']).sum().reset_index(['Code région', 'Code département', 'variable', 'value'])
df
# Out:
#        Code région Code département               variable  value  \
# 0                1              971  Population municipale   1053
# 1                1              971  Population municipale   1465
# 2                1              971  Population municipale   1566
# 3                1              971  Population municipale   1854
# 4                1              971  Population municipale   2472
# ...            ...              ...                    ...    ...
# 58628           94               2B      Population totale   5808
# 58629           94               2B      Population totale   7515
# 58630           94               2B      Population totale   8077
# 58631           94               2B      Population totale   8908
# 58632           94               2B      Population totale  45596
#
#        Code canton  Code arrondissement  Code commune
# 0             20.0                    1           130
# 1             16.0                    2           110
# 2             20.0                    1           131
# 3             20.0                    1           133
# 4             10.0                    2           126
# ...            ...                  ...           ...
# 58628          4.0                    2           120
# 58629         11.0                    3            96
# 58630          5.0                    2            37
# 58631          6.0                    2            42
# 58632         99.0                    2            33
#
# [58633 rows x 7 columns]
